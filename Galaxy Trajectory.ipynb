# %% [markdown]
# # Galaxy Trajectory

# %% [markdown]
# What happens if the initial volocity of S changes?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
from IPython.html.widgets import interact, fixed
import Project_Functions as pf
import Additional_Functions as af
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
a=pf.star_ic(1.0e11,[.15*25,.3*25,.45*25,.6*25,.75*25],[10,20,30,50,75])

# %%
lowV=af.S_ic2(75.0, 25.0, 1.0e11, 1.0e11,.8,1.0)
#added two inputs
#scalar multiple of initial velocity, and angle of trajectiory of S
#.8 times initial velocity

# %%
highV=af.S_ic2(75.0, 25.0, 1.0e11, 1.0e11,1.2,1.0)

# %%
lowA=af.S_ic2(75.0, 25.0, 1.0e11, 1.0e11,1.0,.9)

# %%
highA=af.S_ic2(75.0, 25.0, 1.0e11, 1.0e11,1.0,1.1)

# %%
soln_lv = pf.solve_one_star(a[0], lowV, 1.0e11, 1.0e11, 100.0, 1000)

# %%
soln_hv = pf.solve_one_star(a[0], highV, 1.0e11, 1.0e11, 25.0, 1000)

# %%
soln_la = pf.solve_one_star(a[0], lowA, 1.0e11, 1.0e11, 25.0, 1000)

# %%
soln_ha = pf.solve_one_star(a[0], highA, 1.0e11, 1.0e11, 100.0, 1000)

# %%
py = np.linspace(-100,100,100)
r0 = 25.0
px = -py**2/(4.0*r0) + r0

# %%
solns_lv = pf.solve_all_stars(a, lowV, 1.0e11, 1.0e11, 100.0, 1000)
# Out:
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.

# %%
solns_hv = pf.solve_all_stars(a, highV, 1.0e11, 1.0e11, 25.0, 1000)

# %%
solns_la = pf.solve_all_stars(a, lowA, 1.0e11, 1.0e11, 25.0, 1000)

# %%
solns_ha = pf.solve_all_stars(a, highA, 1.0e11, 1.0e11, 100.0, 1000)

# %% [markdown]
# Low Velocity

# %%
interact(pf.plot_all_solns, solns=fixed(solns_lv), j=(0,999), lim=(25,200,5));

# %%
pf.subplot(solns_lv,[0,50,66,80,150,580,822,888],175)

# %% [markdown]
# High Velocity

# %%
interact(pf.plot_all_solns, solns=fixed(solns_hv), j=(0,999), lim=(25,100,5));

# %%
pf.subplot(solns_hv,[0,130,200,250,300,380,500,755],50)

# %% [markdown]
# Shallow Angle

# %%
interact(pf.plot_all_solns, solns=fixed(solns_la), j=(0,999), lim=(25,100,5));

# %%
pf.subplot(solns_la,[0,115,215,255,310,440,600,790],50)

# %% [markdown]
# Steep Angle

# %%
interact(pf.plot_all_solns, solns=fixed(solns_ha), j=(0,999), lim=(25,500,5));

# %%
pf.subplot(solns_ha,[0,45,60,100,160,200,240,700],100)
