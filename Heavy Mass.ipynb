# %% [markdown]
# # Heavy Mass

# %% [markdown]
# How does the interaction change when S is more massive than M?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
from IPython.html.widgets import interact, fixed
import Project_Functions as pf
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
a=pf.star_ic(1.0e11,[.15*25,.3*25,.45*25,.6*25,.75*25],[10,20,30,50,75])

# %%
b=pf.S_ic(75.0, 25.0, 1.0e11, 5.0e11)
#mass of S is 5 times mass of M

# %%
c=pf.S_ic(75.0,25.0,1.0e11,25.0e11)
#mass of S is 25 times mass of M

# %%
solnb = pf.solve_one_star(a[0], b, 1.0e11, 5.0e11, 25.0, 1000)

# %%
solnc = pf.solve_one_star(a[0], c, 1.0e11, 25.0e11, 25.0, 1000)

# %%
py = np.linspace(-100,100,100)
r0 = 25.0
px = -py**2/(4.0*r0) + r0

# %%
solnsb = pf.solve_all_stars(a, b, 1.0e11, 5.0e11, 25.0, 1000)

# %%
solnsc = pf.solve_all_stars(a, c, 1.0e11, 25.0e11, 25.0, 1000)

# %% [markdown]
# S=5M

# %%
interact(pf.plot_all_solns, solns=fixed(solnsb), j=(0,999), lim=(25,150,5));

# %%
pf.subplot(solnsb,[0,70,110,140,222,300,425,650],85)

# %% [markdown]
# S=25M

# %%
interact(pf.plot_all_solns, solns=fixed(solnsc), j=(0,999), lim=(100,200,5));

# %%
pf.subplot(solnsc,[0,40,88,215,370,500,650,960],150)
