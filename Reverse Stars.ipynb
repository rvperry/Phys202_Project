# %% [markdown]
# # Reverse Stars

# %% [markdown]
# How would the interaction be different if the stars were orbiting clockwise instead of counter clockwise?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
from IPython.html.widgets import interact, fixed
import Project_Functions as pf
import Additional_Functions as af
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
a=af.star_ic2(1.0e11,[.15*25,.3*25,.45*25,.6*25,.75*25],[10,20,30,50,75])
#edited initial conditions of the stars to reverse orbit

# %%
b=pf.S_ic(75.0, 25.0, 1.0e11, 1.0e11)

# %%
soln = pf.solve_one_star(a[0], b, 1.0e11, 1.0e11, 25.0, 1000)

# %%
py = np.linspace(-100,100,100)
r0 = 25.0
px = -py**2/(4.0*r0) + r0

# %%
solns = pf.solve_all_stars(a, b, 1.0e11, 1.0e11, 25.0, 1000)
# Out:
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.

# %%
interact(pf.plot_all_solns, solns=fixed(solns), j=(0,999), lim=(25,150,5));

# %%
pf.subplot(solns,[0,150,200,250,350,475,666,850],100)
